# %% [markdown]
# ## Recurrent neural networks (RNNs)
# - recurrent neural network
# - feed-forward neural network
#
# ## Data preprocessing for RNN
# 1. The original time series
# 2. Create rolling windows
# 3. Stack all windows into a 3D tensor
# 4. Final tensor shape
#
# If there are 11 timepoints and look back is 9 then the sample is 9.
# - think about creating a window with the correct target and the correct lookback
# - how many features
#
# ## Tensors
# - OD Tensor
# - 1D Tensor
# - 2D Tensor
# - 3D Tensor
#
# ## Recurrent neuron
# - the hidden state is the memory of the model
# - has its own weight
# - whatever the previous memory is, will be multipled by that weight
# - add the information and then add the information again
# - you can get an output that is already something useful to us
# - how does this output compare to the true value
#
# ## RNN unfolded
# - Single RNN Cell (one time step)
# - Optional outputs at intermediate steps (may be ignored depending on the task)
# - output used for forecasting
# - the hidden state is the memory that carries information forward. outputs can be produced at each step, but depending on the task we may only use the final one
# - scale the data, you can run into problems with calculating the hidden state
# - adjust the weights, back propagation through time
# - how does this impact all of the calculations
# - it happens through time, 8 sample inputs will be sampled in 8, average those to get the new gradients
#
# ## Activation functions
# - sigmoid functions
# - tanh function
# - ReLU function
# - all against the gradients, and they are all out of hand
# - if a neuron is dead, then its dead through a series of time
# - values are between 0 and 1, taking the derivative will be between that range
# - looking back 10 steps, you will be multipying by .1.
# - this takes away the memory part
# - how far back in time you would like to look? 20 years
# - model does not become smarter with more data
#
# ## Recurrent network
# - each neuron has a different set of features and learns different things in the data
# - they can get adjusted accordingly
# - they are not human interpretable features
# - some of them made sense, some don't align
# - like all model building, there are trial and error
# - in CNN there are convolution layers, and then you feed to different kinds of layers
# - in terms of the architecture, a one-to-one architecture makes 1 prediction
