# %% [markdown]
# # Day 2 RNN

# %% [markdown]
# ### Importing libraries

# %%
# Libraries

import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, GRU
from tensorflow.keras.callbacks import EarlyStopping

random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ### Load & inspect data

# %%
# Load and inspect Bitcoin data

# Download latest version
bitcoin = pd.read_csv('/Users/diyapatel/Documents/GitHub/Advanced-ML/Week 9 /In class assignments/dc.csv')

print("Path to dataset files:", bitcoin)

bitcoin = bitcoin.rename(
    columns={"Unnamed: 0": "date"}
)

bitcoin["date"] = pd.to_datetime(bitcoin["date"])

bitcoin = (
    bitcoin
    .sort_values("date")
    .reset_index(drop=True)
)

print(bitcoin.shape)

bitcoin.head()
# Out:
# Path to dataset files:      Unnamed: 0  open_USD  high_USD   low_USD  close_USD  volume
# 0    2021-01-30  34246.28  34933.00  32825.00   34218.54   43072
# 1    2021-01-29  33368.18  38531.90  31915.40   34252.20  231827
# 2    2021-01-28  30362.19  33783.98  29842.10   33364.86   92621
# 3    2021-01-27  32464.01  32557.29  29241.72   30366.15   95911
# 4    2021-01-26  32254.19  32921.88  30837.37   32467.77   84972
# ..          ...       ...       ...       ...        ...     ...
# 995  2018-05-11   9002.21   9016.80   8341.00    8400.00   48227
# 996  2018-05-10   9310.00   9395.12   8970.00    9002.20   25055
# 997  2018-05-09   9178.00   9390.00   8965.00    9310.00   25673
# 998  2018-05-08   9365.00   9475.70   9060.54    9187.56   25533
# 999  2018-05-07   9661.02   9689.67   9181.00    9365.00   33787
#
# [1000 rows x 6 columns]
# (1000, 6)
#         date  open_USD  high_USD  low_USD  close_USD  volume
# 0 2018-05-07   9661.02   9689.67  9181.00    9365.00   33787
# 1 2018-05-08   9365.00   9475.70  9060.54    9187.56   25533
# 2 2018-05-09   9178.00   9390.00  8965.00    9310.00   25673
# 3 2018-05-10   9310.00   9395.12  8970.00    9002.20   25055
# 4 2018-05-11   9002.21   9016.80  8341.00    8400.00   48227

# %%
# Basic inspection

bitcoin.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1000 non-null   datetime64[us]
#  1   open_USD   1000 non-null   float64
#  2   high_USD   1000 non-null   float64
#  3   low_USD    1000 non-null   float64
#  4   close_USD  1000 non-null   float64
#  5   volume     1000 non-null   int64
# dtypes: datetime64[us](1), float64(4), int64(1)
# memory usage: 47.0 KB

# %%
# Summary statistics

bitcoin.describe()
# Out:
#                       date      open_USD      high_USD       low_USD  \
# count                 1000   1000.000000   1000.000000   1000.000000
# mean   2019-09-18 12:00:00   9285.762120   9542.880270   9011.393200
# min    2018-05-07 00:00:00   3211.710000   3276.500000   3156.260000
# 25%    2019-01-11 18:00:00   6467.192500   6582.255000   6325.015000
# 50%    2019-09-18 12:00:00   8189.695000   8351.630000   8002.045000
# 75%    2020-05-25 06:00:00  10216.860000  10419.562500   9907.977500
# max    2021-01-30 00:00:00  40586.960000  41950.000000  38720.000000
# std                    NaN   5793.522832   6075.604427   5483.524463
#
#           close_USD         volume
# count   1000.000000    1000.000000
# mean    9310.335850   53100.498000
# min     3211.720000    5743.000000
# 25%     6466.762500   30045.750000
# 50%     8189.330000   43795.500000
# 75%    10220.170000   64909.250000
# max    40582.810000  402201.000000
# std     5846.917681   35329.832031

# %% [markdown]
# Visualizing the target variable

# %%
# Visualize closing price over time

plt.figure(figsize=(10, 4))

plt.plot(
    bitcoin["date"],
    bitcoin["close_USD"]
)

plt.title("Bitcoin Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Close Price (USD)")

plt.ticklabel_format(
    style="plain",
    axis="y"
)

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Preparing data for recurrent modeling

# %%
# Prepare Bitcoin data for recurrent models

features = [
    "open_USD",
    "high_USD",
    "low_USD",
    "close_USD",
    "volume"
]

target_col = "close_USD"

bitcoin_model = bitcoin[["date"] + features].copy()

print("Unique dates:", bitcoin_model["date"].nunique())
print("Rows:", len(bitcoin_model))

scaler_bitcoin = MinMaxScaler(feature_range=(0, 1))

scaled_features = scaler_bitcoin.fit_transform(
    bitcoin_model[features]
)

look_back = 10                                                  # use 10 previous days to predict next close

target_index = features.index(target_col)
# Out:
# Unique dates: 1000
# Rows: 1000

# %% [markdown]
# ### Useful functions

# %%
# Function to create recurrent sequence windows

def create_sequences(dataset, target_index, look_back=10):

    X, y = [], []

    for i in range(len(dataset) - look_back):

        X.append(
            dataset[i:i + look_back, :]
        )                                                       # previous look_back days

        y.append(
            dataset[i + look_back, target_index]
        )                                                       # next day's close_USD

    return np.array(X), np.array(y)

# %%
# Function to visualize training curves

def plot_training_curves(history, title):

    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    # Loss
    axes[0].plot(
        history.history["loss"],
        label="Training Loss"
    )

    axes[0].plot(
        history.history["val_loss"],
        label="Validation Loss"
    )

    axes[0].set_title(title + " Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("MSE Loss")

    axes[0].legend()

    # MAE
    axes[1].plot(
        history.history["mean_absolute_error"],
        label="Training MAE"
    )

    axes[1].plot(
        history.history["val_mean_absolute_error"],
        label="Validation MAE"
    )

    axes[1].set_title(title + " MAE")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Mean Absolute Error")

    axes[1].legend()

    plt.tight_layout()

    plt.show()

# %%
# Function to evaluate forecasting performance

def evaluate_and_plot(
    model,
    trainX,
    testX,
    trainY,
    testY,
    scaler,
    target_index,
    title
):

    # Predictions
    train_pred = model.predict(trainX)
    test_pred = model.predict(testX)

    # Create arrays for inverse scaling
    train_dummy = np.zeros((len(train_pred), len(features)))
    test_dummy = np.zeros((len(test_pred), len(features)))

    train_dummy[:, target_index] = train_pred.flatten()
    test_dummy[:, target_index] = test_pred.flatten()

    trainY_dummy = np.zeros((len(trainY), len(features)))
    testY_dummy = np.zeros((len(testY), len(features)))

    trainY_dummy[:, target_index] = trainY
    testY_dummy[:, target_index] = testY

    # Inverse transform
    train_pred_inv = scaler.inverse_transform(train_dummy)[:, target_index]
    test_pred_inv = scaler.inverse_transform(test_dummy)[:, target_index]

    trainY_inv = scaler.inverse_transform(trainY_dummy)[:, target_index]
    testY_inv = scaler.inverse_transform(testY_dummy)[:, target_index]

    # Metrics
    train_rmse = np.sqrt(mean_squared_error(trainY_inv, train_pred_inv))
    test_rmse = np.sqrt(mean_squared_error(testY_inv, test_pred_inv))

    train_mae = mean_absolute_error(trainY_inv, train_pred_inv)
    test_mae = mean_absolute_error(testY_inv, test_pred_inv)

    print(f"{title} Train RMSE: {train_rmse:.2f}")
    print(f"{title} Test RMSE: {test_rmse:.2f}")

    print(f"{title} Train MAE: {train_mae:.2f}")
    print(f"{title} Test MAE: {test_mae:.2f}")

    # Plot predictions
    plt.figure(figsize=(10, 4))

    plt.plot(
        testY_inv,
        label="Actual"
    )

    plt.plot(
        test_pred_inv,
        label="Predicted"
    )

    plt.title(title + " Test Predictions")

    plt.xlabel("Test time index")
    plt.ylabel("Bitcoin Close Price (USD)")

    plt.ticklabel_format(
        style="plain",
        axis="y"
    )

    plt.legend()

    plt.show()

# %%
# Function to compare model metrics

def evaluate_metrics(
    model,
    testX,
    testY,
    scaler,
    target_index
):

    test_pred = model.predict(testX)

    test_dummy = np.zeros((len(test_pred), len(features)))
    test_dummy[:, target_index] = test_pred.flatten()

    testY_dummy = np.zeros((len(testY), len(features)))
    testY_dummy[:, target_index] = testY

    test_pred_inv = scaler.inverse_transform(test_dummy)[:, target_index]
    testY_inv = scaler.inverse_transform(testY_dummy)[:, target_index]

    rmse = np.sqrt(mean_squared_error(testY_inv, test_pred_inv))
    mae = mean_absolute_error(testY_inv, test_pred_inv)

    return rmse, mae

# %% [markdown]
# ### Creating train/test recurrent tensors

# %%
# Create train/test recurrent tensors

train_size = int(len(scaled_features) * 0.8)                    # chronological 80/20 split

train_bitcoin = scaled_features[:train_size]                    # earlier data
test_bitcoin = scaled_features[train_size:]                     # held-out future data

trainX_bitcoin, trainY_bitcoin = create_sequences(
    train_bitcoin,
    target_index,
    look_back
)

testX_bitcoin, testY_bitcoin = create_sequences(
    test_bitcoin,
    target_index,
    look_back
)

print("trainX_bitcoin shape:", trainX_bitcoin.shape)
print("testX_bitcoin shape:", testX_bitcoin.shape)
print("trainY_bitcoin shape:", trainY_bitcoin.shape)
print("testY_bitcoin shape:", testY_bitcoin.shape)
# Out:
# trainX_bitcoin shape: (790, 10, 5)
# testX_bitcoin shape: (190, 10, 5)
# trainY_bitcoin shape: (790,)
# testY_bitcoin shape: (190,)

# %% [markdown]
# ### Baseline SimpleRNN model

# %%
# Build and train baseline SimpleRNN model

simple_rnn_model = Sequential([
    SimpleRNN(
        8,                                     # small baseline recurrent layer
        activation="tanh",                     # standard activation for SimpleRNN
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

simple_rnn_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

simple_rnn_history = simple_rnn_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# /opt/anaconda3/envs/tensorflow_env/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0108 - mean_absolute_error: 0.0820 - val_loss: 0.0113 - val_mean_absolute_error: 0.0747
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - mean_absolute_error: 0.0477 - val_loss: 0.0080 - val_mean_absolute_error: 0.0571
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0402 - val_loss: 0.0062 - val_mean_absolute_error: 0.0496
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0343 - val_loss: 0.0049 - val_mean_absolute_error: 0.0438
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0304 - val_loss: 0.0039 - val_mean_absolute_error: 0.0391
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0279 - val_loss: 0.0032 - val_mean_absolute_error: 0.0353
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0259 - val_loss: 0.0026 - val_mean_absolute_error: 0.0323
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0242 - val_loss: 0.0022 - val_mean_absolute_error: 0.0299
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6651e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0019 - val_mean_absolute_error: 0.0280
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5578e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0016 - val_mean_absolute_error: 0.0264
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6079e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0014 - val_mean_absolute_error: 0.0250
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7854e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0013 - val_mean_absolute_error: 0.0239
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0700e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0012 - val_mean_absolute_error: 0.0228
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4465e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0010 - val_mean_absolute_error: 0.0218
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9029e-04 - mean_absolute_error: 0.0163 - val_loss: 9.4630e-04 - val_mean_absolute_error: 0.0208
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4292e-04 - mean_absolute_error: 0.0155 - val_loss: 8.6039e-04 - val_mean_absolute_error: 0.0199
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0168e-04 - mean_absolute_error: 0.0148 - val_loss: 7.8424e-04 - val_mean_absolute_error: 0.0190
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6580e-04 - mean_absolute_error: 0.0141 - val_loss: 7.1639e-04 - val_mean_absolute_error: 0.0182
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3461e-04 - mean_absolute_error: 0.0135 - val_loss: 6.5577e-04 - val_mean_absolute_error: 0.0174
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0751e-04 - mean_absolute_error: 0.0130 - val_loss: 6.0155e-04 - val_mean_absolute_error: 0.0166
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8395e-04 - mean_absolute_error: 0.0125 - val_loss: 5.5307e-04 - val_mean_absolute_error: 0.0159
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6346e-04 - mean_absolute_error: 0.0121 - val_loss: 5.0976e-04 - val_mean_absolute_error: 0.0153
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4563e-04 - mean_absolute_error: 0.0116 - val_loss: 4.7113e-04 - val_mean_absolute_error: 0.0147
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3011e-04 - mean_absolute_error: 0.0113 - val_loss: 4.3671e-04 - val_mean_absolute_error: 0.0142
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1657e-04 - mean_absolute_error: 0.0109 - val_loss: 4.0609e-04 - val_mean_absolute_error: 0.0137
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0475e-04 - mean_absolute_error: 0.0106 - val_loss: 3.7890e-04 - val_mean_absolute_error: 0.0133
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9443e-04 - mean_absolute_error: 0.0104 - val_loss: 3.5479e-04 - val_mean_absolute_error: 0.0129
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8540e-04 - mean_absolute_error: 0.0101 - val_loss: 3.3342e-04 - val_mean_absolute_error: 0.0125
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7750e-04 - mean_absolute_error: 0.0099 - val_loss: 3.1452e-04 - val_mean_absolute_error: 0.0122
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7058e-04 - mean_absolute_error: 0.0097 - val_loss: 2.9782e-04 - val_mean_absolute_error: 0.0118
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6452e-04 - mean_absolute_error: 0.0095 - val_loss: 2.8306e-04 - val_mean_absolute_error: 0.0115
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5921e-04 - mean_absolute_error: 0.0093 - val_loss: 2.7003e-04 - val_mean_absolute_error: 0.0113
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5456e-04 - mean_absolute_error: 0.0091 - val_loss: 2.5853e-04 - val_mean_absolute_error: 0.0110
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5048e-04 - mean_absolute_error: 0.0090 - val_loss: 2.4838e-04 - val_mean_absolute_error: 0.0108
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4691e-04 - mean_absolute_error: 0.0089 - val_loss: 2.3943e-04 - val_mean_absolute_error: 0.0106
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4377e-04 - mean_absolute_error: 0.0087 - val_loss: 2.3152e-04 - val_mean_absolute_error: 0.0104
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4101e-04 - mean_absolute_error: 0.0086 - val_loss: 2.2454e-04 - val_mean_absolute_error: 0.0102
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3859e-04 - mean_absolute_error: 0.0085 - val_loss: 2.1838e-04 - val_mean_absolute_error: 0.0100
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3645e-04 - mean_absolute_error: 0.0085 - val_loss: 2.1293e-04 - val_mean_absolute_error: 0.0099
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3457e-04 - mean_absolute_error: 0.0084 - val_loss: 2.0810e-04 - val_mean_absolute_error: 0.0098
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3290e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0383e-04 - val_mean_absolute_error: 0.0097
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3141e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0004e-04 - val_mean_absolute_error: 0.0096
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3007e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9668e-04 - val_mean_absolute_error: 0.0095
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2886e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9370e-04 - val_mean_absolute_error: 0.0094
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2777e-04 - mean_absolute_error: 0.0081 - val_loss: 1.9105e-04 - val_mean_absolute_error: 0.0094
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2677e-04 - mean_absolute_error: 0.0081 - val_loss: 1.8868e-04 - val_mean_absolute_error: 0.0093
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2584e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8659e-04 - val_mean_absolute_error: 0.0093
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2498e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8472e-04 - val_mean_absolute_error: 0.0092
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2417e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8307e-04 - val_mean_absolute_error: 0.0092
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2341e-04 - mean_absolute_error: 0.0079 - val_loss: 1.8160e-04 - val_mean_absolute_error: 0.0091

# %% [markdown]
# Visualizing training

# %%
# Visualize SimpleRNN training performance

plot_training_curves(
    simple_rnn_history,
    "Baseline SimpleRNN"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate SimpleRNN on held-out future test data

evaluate_and_plot(
    simple_rnn_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Baseline SimpleRNN"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Baseline SimpleRNN Train RMSE: 493.52
# Baseline SimpleRNN Test RMSE: 3953.11
# Baseline SimpleRNN Train MAE: 364.83
# Baseline SimpleRNN Test MAE: 2409.82

# %% [markdown]
# ### Baseline LSTM Model

# %%
# Build and train baseline LSTM model

lstm_model = Sequential([
    LSTM(
        8,                                     # small baseline LSTM layer
        activation="tanh",                     # standard LSTM hidden-state activation
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

lstm_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

lstm_history = lstm_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# /opt/anaconda3/envs/tensorflow_env/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0018 - mean_absolute_error: 0.0332 - val_loss: 0.0052 - val_mean_absolute_error: 0.0536
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0257 - val_loss: 0.0043 - val_mean_absolute_error: 0.0484
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7141e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0033 - val_mean_absolute_error: 0.0409
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8698e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0024 - val_mean_absolute_error: 0.0340
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2297e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0019 - val_mean_absolute_error: 0.0293
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8944e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0015 - val_mean_absolute_error: 0.0259
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6544e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0012 - val_mean_absolute_error: 0.0231
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4755e-04 - mean_absolute_error: 0.0122 - val_loss: 9.9588e-04 - val_mean_absolute_error: 0.0206
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3489e-04 - mean_absolute_error: 0.0118 - val_loss: 8.1265e-04 - val_mean_absolute_error: 0.0184
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2655e-04 - mean_absolute_error: 0.0116 - val_loss: 6.7026e-04 - val_mean_absolute_error: 0.0165
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2148e-04 - mean_absolute_error: 0.0114 - val_loss: 5.6249e-04 - val_mean_absolute_error: 0.0149
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1859e-04 - mean_absolute_error: 0.0112 - val_loss: 4.8299e-04 - val_mean_absolute_error: 0.0137
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1692e-04 - mean_absolute_error: 0.0111 - val_loss: 4.2545e-04 - val_mean_absolute_error: 0.0128
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1573e-04 - mean_absolute_error: 0.0110 - val_loss: 3.8417e-04 - val_mean_absolute_error: 0.0121
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1456e-04 - mean_absolute_error: 0.0110 - val_loss: 3.5447e-04 - val_mean_absolute_error: 0.0117
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1317e-04 - mean_absolute_error: 0.0109 - val_loss: 3.3280e-04 - val_mean_absolute_error: 0.0113
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1150e-04 - mean_absolute_error: 0.0108 - val_loss: 3.1663e-04 - val_mean_absolute_error: 0.0110
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0954e-04 - mean_absolute_error: 0.0108 - val_loss: 3.0425e-04 - val_mean_absolute_error: 0.0107
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0735e-04 - mean_absolute_error: 0.0107 - val_loss: 2.9449e-04 - val_mean_absolute_error: 0.0106
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0497e-04 - mean_absolute_error: 0.0106 - val_loss: 2.8657e-04 - val_mean_absolute_error: 0.0104
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0247e-04 - mean_absolute_error: 0.0105 - val_loss: 2.7997e-04 - val_mean_absolute_error: 0.0103
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9988e-04 - mean_absolute_error: 0.0105 - val_loss: 2.7434e-04 - val_mean_absolute_error: 0.0101
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9723e-04 - mean_absolute_error: 0.0104 - val_loss: 2.6942e-04 - val_mean_absolute_error: 0.0100
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9457e-04 - mean_absolute_error: 0.0103 - val_loss: 2.6506e-04 - val_mean_absolute_error: 0.0100
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9189e-04 - mean_absolute_error: 0.0102 - val_loss: 2.6112e-04 - val_mean_absolute_error: 0.0099
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8924e-04 - mean_absolute_error: 0.0101 - val_loss: 2.5753e-04 - val_mean_absolute_error: 0.0098
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8660e-04 - mean_absolute_error: 0.0100 - val_loss: 2.5422e-04 - val_mean_absolute_error: 0.0098
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8401e-04 - mean_absolute_error: 0.0100 - val_loss: 2.5114e-04 - val_mean_absolute_error: 0.0097
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8147e-04 - mean_absolute_error: 0.0099 - val_loss: 2.4826e-04 - val_mean_absolute_error: 0.0097
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7897e-04 - mean_absolute_error: 0.0098 - val_loss: 2.4556e-04 - val_mean_absolute_error: 0.0097
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7653e-04 - mean_absolute_error: 0.0097 - val_loss: 2.4301e-04 - val_mean_absolute_error: 0.0096
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7416e-04 - mean_absolute_error: 0.0096 - val_loss: 2.4059e-04 - val_mean_absolute_error: 0.0096
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7184e-04 - mean_absolute_error: 0.0096 - val_loss: 2.3830e-04 - val_mean_absolute_error: 0.0096
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6959e-04 - mean_absolute_error: 0.0095 - val_loss: 2.3612e-04 - val_mean_absolute_error: 0.0095
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6740e-04 - mean_absolute_error: 0.0094 - val_loss: 2.3405e-04 - val_mean_absolute_error: 0.0095
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6527e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3207e-04 - val_mean_absolute_error: 0.0095
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6321e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3019e-04 - val_mean_absolute_error: 0.0095
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6121e-04 - mean_absolute_error: 0.0092 - val_loss: 2.2839e-04 - val_mean_absolute_error: 0.0095
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5927e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2666e-04 - val_mean_absolute_error: 0.0094
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5739e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2501e-04 - val_mean_absolute_error: 0.0094
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5557e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2343e-04 - val_mean_absolute_error: 0.0094
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5381e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2191e-04 - val_mean_absolute_error: 0.0094
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5210e-04 - mean_absolute_error: 0.0089 - val_loss: 2.2045e-04 - val_mean_absolute_error: 0.0094
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5044e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1904e-04 - val_mean_absolute_error: 0.0094
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4884e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1768e-04 - val_mean_absolute_error: 0.0094
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4728e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1637e-04 - val_mean_absolute_error: 0.0094
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4577e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1510e-04 - val_mean_absolute_error: 0.0094
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4431e-04 - mean_absolute_error: 0.0086 - val_loss: 2.1387e-04 - val_mean_absolute_error: 0.0094
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4289e-04 - mean_absolute_error: 0.0086 - val_loss: 2.1267e-04 - val_mean_absolute_error: 0.0094
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4151e-04 - mean_absolute_error: 0.0086 - val_loss: 2.1150e-04 - val_mean_absolute_error: 0.0094

# %% [markdown]
# Visualizing training

# %%
# Visualize LSTM training performance

plot_training_curves(
    lstm_history,
    "Baseline LSTM"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate LSTM on held-out future test data

evaluate_and_plot(
    lstm_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Baseline LSTM"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Baseline LSTM Train RMSE: 434.39
# Baseline LSTM Test RMSE: 2398.13
# Baseline LSTM Train MAE: 299.69
# Baseline LSTM Test MAE: 1580.11

# %% [markdown]
# ### Baseline GRU model

# %%
# Build and train baseline GRU model

gru_model = Sequential([
    GRU(
        8,                                      # intentionally small baseline GRU layer
        activation="tanh",                     # standard GRU hidden-state activation
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

gru_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

gru_history = gru_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# /opt/anaconda3/envs/tensorflow_env/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0039 - mean_absolute_error: 0.0515 - val_loss: 0.0022 - val_mean_absolute_error: 0.0363
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0279 - val_loss: 0.0020 - val_mean_absolute_error: 0.0395
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3650e-04 - mean_absolute_error: 0.0147 - val_loss: 8.5610e-04 - val_mean_absolute_error: 0.0239
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5692e-04 - mean_absolute_error: 0.0092 - val_loss: 3.7739e-04 - val_mean_absolute_error: 0.0138
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6610e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3522e-04 - val_mean_absolute_error: 0.0105
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8008e-04 - mean_absolute_error: 0.0095 - val_loss: 1.7585e-04 - val_mean_absolute_error: 0.0090
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8698e-04 - mean_absolute_error: 0.0096 - val_loss: 1.4778e-04 - val_mean_absolute_error: 0.0082
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8542e-04 - mean_absolute_error: 0.0096 - val_loss: 1.3687e-04 - val_mean_absolute_error: 0.0079
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7644e-04 - mean_absolute_error: 0.0094 - val_loss: 1.3468e-04 - val_mean_absolute_error: 0.0080
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6288e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3660e-04 - val_mean_absolute_error: 0.0083
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4787e-04 - mean_absolute_error: 0.0087 - val_loss: 1.4010e-04 - val_mean_absolute_error: 0.0085
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3379e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4387e-04 - val_mean_absolute_error: 0.0088
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2194e-04 - mean_absolute_error: 0.0080 - val_loss: 1.4737e-04 - val_mean_absolute_error: 0.0090
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1275e-04 - mean_absolute_error: 0.0076 - val_loss: 1.5053e-04 - val_mean_absolute_error: 0.0091
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0608e-04 - mean_absolute_error: 0.0074 - val_loss: 1.5349e-04 - val_mean_absolute_error: 0.0093
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0154e-04 - mean_absolute_error: 0.0072 - val_loss: 1.5648e-04 - val_mean_absolute_error: 0.0094
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.8688e-05 - mean_absolute_error: 0.0071 - val_loss: 1.5971e-04 - val_mean_absolute_error: 0.0096
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7116e-05 - mean_absolute_error: 0.0070 - val_loss: 1.6333e-04 - val_mean_absolute_error: 0.0098
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6519e-05 - mean_absolute_error: 0.0070 - val_loss: 1.6747e-04 - val_mean_absolute_error: 0.0100
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6686e-05 - mean_absolute_error: 0.0070 - val_loss: 1.7219e-04 - val_mean_absolute_error: 0.0102
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7492e-05 - mean_absolute_error: 0.0070 - val_loss: 1.7759e-04 - val_mean_absolute_error: 0.0104
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.8869e-05 - mean_absolute_error: 0.0071 - val_loss: 1.8374e-04 - val_mean_absolute_error: 0.0107
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0079e-04 - mean_absolute_error: 0.0072 - val_loss: 1.9071e-04 - val_mean_absolute_error: 0.0111
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0323e-04 - mean_absolute_error: 0.0073 - val_loss: 1.9856e-04 - val_mean_absolute_error: 0.0114
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0620e-04 - mean_absolute_error: 0.0074 - val_loss: 2.0731e-04 - val_mean_absolute_error: 0.0117
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0967e-04 - mean_absolute_error: 0.0076 - val_loss: 2.1692e-04 - val_mean_absolute_error: 0.0121
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1360e-04 - mean_absolute_error: 0.0078 - val_loss: 2.2728e-04 - val_mean_absolute_error: 0.0125
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1791e-04 - mean_absolute_error: 0.0080 - val_loss: 2.3816e-04 - val_mean_absolute_error: 0.0129
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2248e-04 - mean_absolute_error: 0.0082 - val_loss: 2.4922e-04 - val_mean_absolute_error: 0.0133
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2712e-04 - mean_absolute_error: 0.0084 - val_loss: 2.5998e-04 - val_mean_absolute_error: 0.0136
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3159e-04 - mean_absolute_error: 0.0086 - val_loss: 2.6989e-04 - val_mean_absolute_error: 0.0139
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3563e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7837e-04 - val_mean_absolute_error: 0.0142
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3897e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8495e-04 - val_mean_absolute_error: 0.0144
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4142e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8934e-04 - val_mean_absolute_error: 0.0145
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4289e-04 - mean_absolute_error: 0.0091 - val_loss: 2.9156e-04 - val_mean_absolute_error: 0.0146
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4342e-04 - mean_absolute_error: 0.0091 - val_loss: 2.9192e-04 - val_mean_absolute_error: 0.0146
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4320e-04 - mean_absolute_error: 0.0091 - val_loss: 2.9093e-04 - val_mean_absolute_error: 0.0145
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4246e-04 - mean_absolute_error: 0.0091 - val_loss: 2.8919e-04 - val_mean_absolute_error: 0.0145
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4147e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8722e-04 - val_mean_absolute_error: 0.0144
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4044e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8540e-04 - val_mean_absolute_error: 0.0144
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3950e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8392e-04 - val_mean_absolute_error: 0.0143
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3873e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8284e-04 - val_mean_absolute_error: 0.0143
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3812e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8208e-04 - val_mean_absolute_error: 0.0143
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3764e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8152e-04 - val_mean_absolute_error: 0.0142
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3723e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8104e-04 - val_mean_absolute_error: 0.0142
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3683e-04 - mean_absolute_error: 0.0088 - val_loss: 2.8052e-04 - val_mean_absolute_error: 0.0142
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3640e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7990e-04 - val_mean_absolute_error: 0.0142
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3592e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7916e-04 - val_mean_absolute_error: 0.0142
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3539e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7829e-04 - val_mean_absolute_error: 0.0141
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3481e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7734e-04 - val_mean_absolute_error: 0.0141

# %% [markdown]
# Visualizing training

# %%
# Visualize GRU training performance

plot_training_curves(
    gru_history,
    "Baseline GRU"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate GRU on held-out future test data

evaluate_and_plot(
    gru_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Baseline GRU"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Baseline GRU Train RMSE: 560.80
# Baseline GRU Test RMSE: 4732.63
# Baseline GRU Train MAE: 438.16
# Baseline GRU Test MAE: 3248.33

# %% [markdown]
# ### Activity: Improving Forecasting Models
#
# Improve each of the baseline three recurrent models (SimpleRNN, LSTM, and GRU) and compare their forecasting performance against the XGBoost models shown below. You should provide the code for each improved model and include a markdown cell after each model describing what you changed, what you explored, and how the changes affected performance. After completing your experiments, provide a short overall summary discussing which approaches appeared most effective, which models were easiest or hardest to tune, and what tradeoffs you observed between model complexity, training stability, and forecasting performance.

# %%
# Your SimpleRNN code
# Build and train baseline SimpleRNN model

simple_rnn_model = Sequential([
    SimpleRNN(
        16,                                     # increase hidden units
        activation="tanh",  
        recurrent_dropout = 0.2, #add regularization                   # standard activation for SimpleRNN
        input_shape=(look_back==7, trainX_bitcoin.shape[2])   #look back = 7
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

simple_rnn_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

simple_rnn_history = simple_rnn_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# /opt/anaconda3/envs/tensorflow_env/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1171 - mean_absolute_error: 0.2634 - val_loss: 0.0103 - val_mean_absolute_error: 0.0756
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0317 - mean_absolute_error: 0.1367 - val_loss: 0.0079 - val_mean_absolute_error: 0.0663
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0180 - mean_absolute_error: 0.1047 - val_loss: 0.0063 - val_mean_absolute_error: 0.0585
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0133 - mean_absolute_error: 0.0875 - val_loss: 0.0055 - val_mean_absolute_error: 0.0539
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0091 - mean_absolute_error: 0.0723 - val_loss: 0.0046 - val_mean_absolute_error: 0.0487
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0711 - val_loss: 0.0041 - val_mean_absolute_error: 0.0472
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0619 - val_loss: 0.0036 - val_mean_absolute_error: 0.0444
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - mean_absolute_error: 0.0557 - val_loss: 0.0030 - val_mean_absolute_error: 0.0397
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0543 - val_loss: 0.0026 - val_mean_absolute_error: 0.0375
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0498 - val_loss: 0.0024 - val_mean_absolute_error: 0.0359
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0455 - val_loss: 0.0020 - val_mean_absolute_error: 0.0307
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0428 - val_loss: 0.0019 - val_mean_absolute_error: 0.0322
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0401 - val_loss: 0.0018 - val_mean_absolute_error: 0.0317
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0399 - val_loss: 0.0016 - val_mean_absolute_error: 0.0278
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0381 - val_loss: 0.0013 - val_mean_absolute_error: 0.0258
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - mean_absolute_error: 0.0362 - val_loss: 0.0012 - val_mean_absolute_error: 0.0221
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0336 - val_loss: 0.0011 - val_mean_absolute_error: 0.0238
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0325 - val_loss: 0.0010 - val_mean_absolute_error: 0.0224
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0311 - val_loss: 9.4849e-04 - val_mean_absolute_error: 0.0208
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0290 - val_loss: 8.7835e-04 - val_mean_absolute_error: 0.0205
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0287 - val_loss: 8.1516e-04 - val_mean_absolute_error: 0.0197
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0266 - val_loss: 7.7375e-04 - val_mean_absolute_error: 0.0194
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0255 - val_loss: 7.4115e-04 - val_mean_absolute_error: 0.0188
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0244 - val_loss: 6.6022e-04 - val_mean_absolute_error: 0.0173
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7746e-04 - mean_absolute_error: 0.0219 - val_loss: 6.2680e-04 - val_mean_absolute_error: 0.0172
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3672e-04 - mean_absolute_error: 0.0222 - val_loss: 6.0846e-04 - val_mean_absolute_error: 0.0162
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3092e-04 - mean_absolute_error: 0.0202 - val_loss: 5.8605e-04 - val_mean_absolute_error: 0.0160
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6684e-04 - mean_absolute_error: 0.0196 - val_loss: 5.4775e-04 - val_mean_absolute_error: 0.0155
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9985e-04 - mean_absolute_error: 0.0197 - val_loss: 5.1578e-04 - val_mean_absolute_error: 0.0148
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4010e-04 - mean_absolute_error: 0.0206 - val_loss: 4.8553e-04 - val_mean_absolute_error: 0.0145
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3560e-04 - mean_absolute_error: 0.0189 - val_loss: 4.5702e-04 - val_mean_absolute_error: 0.0141
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8837e-04 - mean_absolute_error: 0.0184 - val_loss: 4.3093e-04 - val_mean_absolute_error: 0.0136
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0572e-04 - mean_absolute_error: 0.0184 - val_loss: 3.9983e-04 - val_mean_absolute_error: 0.0133
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6499e-04 - mean_absolute_error: 0.0179 - val_loss: 3.8098e-04 - val_mean_absolute_error: 0.0127
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0200e-04 - mean_absolute_error: 0.0166 - val_loss: 3.7524e-04 - val_mean_absolute_error: 0.0125
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0064e-04 - mean_absolute_error: 0.0162 - val_loss: 3.8007e-04 - val_mean_absolute_error: 0.0124
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8547e-04 - mean_absolute_error: 0.0165 - val_loss: 3.3338e-04 - val_mean_absolute_error: 0.0121
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9390e-04 - mean_absolute_error: 0.0150 - val_loss: 3.2276e-04 - val_mean_absolute_error: 0.0116
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5137e-04 - mean_absolute_error: 0.0158 - val_loss: 2.9872e-04 - val_mean_absolute_error: 0.0112
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1106e-04 - mean_absolute_error: 0.0149 - val_loss: 2.8637e-04 - val_mean_absolute_error: 0.0109
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4044e-04 - mean_absolute_error: 0.0138 - val_loss: 2.7640e-04 - val_mean_absolute_error: 0.0107
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5406e-04 - mean_absolute_error: 0.0140 - val_loss: 2.6412e-04 - val_mean_absolute_error: 0.0107
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4829e-04 - mean_absolute_error: 0.0139 - val_loss: 2.5350e-04 - val_mean_absolute_error: 0.0102
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9679e-04 - mean_absolute_error: 0.0127 - val_loss: 2.3963e-04 - val_mean_absolute_error: 0.0101
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1116e-04 - mean_absolute_error: 0.0132 - val_loss: 2.4276e-04 - val_mean_absolute_error: 0.0099
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9404e-04 - mean_absolute_error: 0.0129 - val_loss: 2.2583e-04 - val_mean_absolute_error: 0.0097
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7277e-04 - mean_absolute_error: 0.0127 - val_loss: 2.1570e-04 - val_mean_absolute_error: 0.0095
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8412e-04 - mean_absolute_error: 0.0127 - val_loss: 2.0155e-04 - val_mean_absolute_error: 0.0094
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6329e-04 - mean_absolute_error: 0.0119 - val_loss: 2.0985e-04 - val_mean_absolute_error: 0.0093
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4874e-04 - mean_absolute_error: 0.0120 - val_loss: 1.9188e-04 - val_mean_absolute_error: 0.0090

# %%
plot_training_curves(
    simple_rnn_history,
    "Improved SimpleRNN"
)

# %%
# Evaluate SimpleRNN on held-out future test data

evaluate_and_plot(
    simple_rnn_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Improved SimpleRNN"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Improved SimpleRNN Train RMSE: 383.25
# Improved SimpleRNN Test RMSE: 2839.88
# Improved SimpleRNN Train MAE: 264.96
# Improved SimpleRNN Test MAE: 1645.44

# %% [markdown]
# The improved model had a lower RMSE and MAE value on both the training and test sets, having more accurate forecasts overall. The largest improvements occurred on the test set, where RMSE decreased by 28% and MAE decreased by 32%. The combination of a larger recurrent layer, a 7-day lookback window, and the recurrent dropout helped the model learn meaningful patterns and reduce overfitting having a better generalization to the unseen Bitcoin data.

# %%
# Your LSTM code
lstm_model = Sequential([
    LSTM(
        24,                                     # increase hidden layer to 24
        activation="tanh",                     # standard LSTM hidden-state activation
        input_shape=(look_back==14, trainX_bitcoin.shape[2]) #look back = 14
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

lstm_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

lstm_history = lstm_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# /opt/anaconda3/envs/tensorflow_env/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0067 - mean_absolute_error: 0.0677 - val_loss: 0.0014 - val_mean_absolute_error: 0.0328
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mean_absolute_error: 0.0436 - val_loss: 7.6532e-04 - val_mean_absolute_error: 0.0225
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0283 - val_loss: 4.9352e-04 - val_mean_absolute_error: 0.0174
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0514e-04 - mean_absolute_error: 0.0154 - val_loss: 4.0901e-04 - val_mean_absolute_error: 0.0153
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5718e-04 - mean_absolute_error: 0.0116 - val_loss: 3.7490e-04 - val_mean_absolute_error: 0.0140
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2928e-04 - mean_absolute_error: 0.0109 - val_loss: 3.4081e-04 - val_mean_absolute_error: 0.0131
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2252e-04 - mean_absolute_error: 0.0107 - val_loss: 3.1178e-04 - val_mean_absolute_error: 0.0124
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1768e-04 - mean_absolute_error: 0.0106 - val_loss: 2.9289e-04 - val_mean_absolute_error: 0.0118
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1317e-04 - mean_absolute_error: 0.0104 - val_loss: 2.8096e-04 - val_mean_absolute_error: 0.0114
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0910e-04 - mean_absolute_error: 0.0103 - val_loss: 2.7366e-04 - val_mean_absolute_error: 0.0110
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0541e-04 - mean_absolute_error: 0.0102 - val_loss: 2.6921e-04 - val_mean_absolute_error: 0.0107
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0201e-04 - mean_absolute_error: 0.0101 - val_loss: 2.6630e-04 - val_mean_absolute_error: 0.0104
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9883e-04 - mean_absolute_error: 0.0100 - val_loss: 2.6407e-04 - val_mean_absolute_error: 0.0103
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9583e-04 - mean_absolute_error: 0.0100 - val_loss: 2.6198e-04 - val_mean_absolute_error: 0.0101
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9296e-04 - mean_absolute_error: 0.0099 - val_loss: 2.5974e-04 - val_mean_absolute_error: 0.0100
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9019e-04 - mean_absolute_error: 0.0098 - val_loss: 2.5723e-04 - val_mean_absolute_error: 0.0100
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8750e-04 - mean_absolute_error: 0.0098 - val_loss: 2.5441e-04 - val_mean_absolute_error: 0.0099
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8487e-04 - mean_absolute_error: 0.0097 - val_loss: 2.5130e-04 - val_mean_absolute_error: 0.0098
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8229e-04 - mean_absolute_error: 0.0097 - val_loss: 2.4795e-04 - val_mean_absolute_error: 0.0098
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7974e-04 - mean_absolute_error: 0.0096 - val_loss: 2.4442e-04 - val_mean_absolute_error: 0.0097
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7721e-04 - mean_absolute_error: 0.0096 - val_loss: 2.4076e-04 - val_mean_absolute_error: 0.0097
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7471e-04 - mean_absolute_error: 0.0095 - val_loss: 2.3703e-04 - val_mean_absolute_error: 0.0097
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7222e-04 - mean_absolute_error: 0.0095 - val_loss: 2.3327e-04 - val_mean_absolute_error: 0.0096
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6974e-04 - mean_absolute_error: 0.0094 - val_loss: 2.2951e-04 - val_mean_absolute_error: 0.0096
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6729e-04 - mean_absolute_error: 0.0093 - val_loss: 2.2578e-04 - val_mean_absolute_error: 0.0095
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6484e-04 - mean_absolute_error: 0.0093 - val_loss: 2.2209e-04 - val_mean_absolute_error: 0.0095
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6242e-04 - mean_absolute_error: 0.0092 - val_loss: 2.1848e-04 - val_mean_absolute_error: 0.0095
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6002e-04 - mean_absolute_error: 0.0091 - val_loss: 2.1495e-04 - val_mean_absolute_error: 0.0094
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5764e-04 - mean_absolute_error: 0.0091 - val_loss: 2.1152e-04 - val_mean_absolute_error: 0.0094
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5529e-04 - mean_absolute_error: 0.0090 - val_loss: 2.0818e-04 - val_mean_absolute_error: 0.0094
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5296e-04 - mean_absolute_error: 0.0089 - val_loss: 2.0495e-04 - val_mean_absolute_error: 0.0094
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5068e-04 - mean_absolute_error: 0.0089 - val_loss: 2.0182e-04 - val_mean_absolute_error: 0.0093
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4843e-04 - mean_absolute_error: 0.0088 - val_loss: 1.9881e-04 - val_mean_absolute_error: 0.0093
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4622e-04 - mean_absolute_error: 0.0087 - val_loss: 1.9591e-04 - val_mean_absolute_error: 0.0093
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4405e-04 - mean_absolute_error: 0.0087 - val_loss: 1.9313e-04 - val_mean_absolute_error: 0.0093
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4193e-04 - mean_absolute_error: 0.0086 - val_loss: 1.9047e-04 - val_mean_absolute_error: 0.0092
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3985e-04 - mean_absolute_error: 0.0086 - val_loss: 1.8793e-04 - val_mean_absolute_error: 0.0092
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3783e-04 - mean_absolute_error: 0.0085 - val_loss: 1.8551e-04 - val_mean_absolute_error: 0.0092
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3585e-04 - mean_absolute_error: 0.0084 - val_loss: 1.8321e-04 - val_mean_absolute_error: 0.0092
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3393e-04 - mean_absolute_error: 0.0084 - val_loss: 1.8104e-04 - val_mean_absolute_error: 0.0092
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3206e-04 - mean_absolute_error: 0.0083 - val_loss: 1.7899e-04 - val_mean_absolute_error: 0.0091
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3024e-04 - mean_absolute_error: 0.0082 - val_loss: 1.7706e-04 - val_mean_absolute_error: 0.0091
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2848e-04 - mean_absolute_error: 0.0082 - val_loss: 1.7525e-04 - val_mean_absolute_error: 0.0091
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2678e-04 - mean_absolute_error: 0.0081 - val_loss: 1.7357e-04 - val_mean_absolute_error: 0.0091
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2513e-04 - mean_absolute_error: 0.0081 - val_loss: 1.7202e-04 - val_mean_absolute_error: 0.0091
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2354e-04 - mean_absolute_error: 0.0080 - val_loss: 1.7058e-04 - val_mean_absolute_error: 0.0091
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2201e-04 - mean_absolute_error: 0.0080 - val_loss: 1.6927e-04 - val_mean_absolute_error: 0.0091
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2053e-04 - mean_absolute_error: 0.0079 - val_loss: 1.6808e-04 - val_mean_absolute_error: 0.0091
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1911e-04 - mean_absolute_error: 0.0079 - val_loss: 1.6700e-04 - val_mean_absolute_error: 0.0091
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1774e-04 - mean_absolute_error: 0.0078 - val_loss: 1.6604e-04 - val_mean_absolute_error: 0.0091

# %%
# Visualize LSTM training performance

plot_training_curves(
    lstm_history,
    "Improved LSTM"
)

# %%
# Evaluate LSTM on held-out future test data

evaluate_and_plot(
    lstm_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Improved LSTM"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Improved LSTM Train RMSE: 410.25
# Improved LSTM Test RMSE: 2337.83
# Improved LSTM Train MAE: 286.39
# Improved LSTM Test MAE: 1567.22

# %% [markdown]
# Here I experimented by increasing the number of LSTM units to 24 and increased the lookback window to 14 time steps. The improved LSTM model gave a lower RMSE and MAE values both on the training and test datasets. The reduction in training errors shows that the larger hidden layer is able to learn the underlying patterns in the data more effectively. The 14-step lookback window gave more previous context which does slightly improve the model's ability to generalize on the unseen data.

# %%
# Your GRU code
gru_model = Sequential([
    GRU(
        16,                                      # increase hidden layers to 16
        activation="tanh",                     # standard GRU hidden-state activation
        input_shape=(look_back==14, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

gru_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

gru_history = gru_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=32,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0191 - mean_absolute_error: 0.1141 - val_loss: 0.0040 - val_mean_absolute_error: 0.0563
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0078 - mean_absolute_error: 0.0698 - val_loss: 0.0015 - val_mean_absolute_error: 0.0358
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0058 - mean_absolute_error: 0.0654 - val_loss: 0.0025 - val_mean_absolute_error: 0.0439
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mean_absolute_error: 0.0473 - val_loss: 0.0012 - val_mean_absolute_error: 0.0297
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mean_absolute_error: 0.0406 - val_loss: 8.0677e-04 - val_mean_absolute_error: 0.0244
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0323 - val_loss: 5.8199e-04 - val_mean_absolute_error: 0.0202
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2492e-04 - mean_absolute_error: 0.0249 - val_loss: 4.3489e-04 - val_mean_absolute_error: 0.0166
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5989e-04 - mean_absolute_error: 0.0192 - val_loss: 3.8318e-04 - val_mean_absolute_error: 0.0145
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5160e-04 - mean_absolute_error: 0.0148 - val_loss: 3.6095e-04 - val_mean_absolute_error: 0.0133
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5135e-04 - mean_absolute_error: 0.0122 - val_loss: 3.4861e-04 - val_mean_absolute_error: 0.0130
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0768e-04 - mean_absolute_error: 0.0108 - val_loss: 3.3163e-04 - val_mean_absolute_error: 0.0127
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8899e-04 - mean_absolute_error: 0.0100 - val_loss: 3.0960e-04 - val_mean_absolute_error: 0.0123
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7927e-04 - mean_absolute_error: 0.0096 - val_loss: 2.8648e-04 - val_mean_absolute_error: 0.0119
# Epoch 14/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7259e-04 - mean_absolute_error: 0.0093 - val_loss: 2.6559e-04 - val_mean_absolute_error: 0.0115
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6720e-04 - mean_absolute_error: 0.0091 - val_loss: 2.4850e-04 - val_mean_absolute_error: 0.0111
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6257e-04 - mean_absolute_error: 0.0090 - val_loss: 2.3531e-04 - val_mean_absolute_error: 0.0108
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5851e-04 - mean_absolute_error: 0.0088 - val_loss: 2.2554e-04 - val_mean_absolute_error: 0.0105
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5492e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1853e-04 - val_mean_absolute_error: 0.0103
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5171e-04 - mean_absolute_error: 0.0085 - val_loss: 2.1367e-04 - val_mean_absolute_error: 0.0101
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4882e-04 - mean_absolute_error: 0.0084 - val_loss: 2.1043e-04 - val_mean_absolute_error: 0.0099
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4621e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0838e-04 - val_mean_absolute_error: 0.0098
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4383e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0715e-04 - val_mean_absolute_error: 0.0097
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4163e-04 - mean_absolute_error: 0.0082 - val_loss: 2.0647e-04 - val_mean_absolute_error: 0.0096
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3958e-04 - mean_absolute_error: 0.0081 - val_loss: 2.0611e-04 - val_mean_absolute_error: 0.0095
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3766e-04 - mean_absolute_error: 0.0080 - val_loss: 2.0591e-04 - val_mean_absolute_error: 0.0094
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3584e-04 - mean_absolute_error: 0.0080 - val_loss: 2.0575e-04 - val_mean_absolute_error: 0.0093
# Epoch 27/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3411e-04 - mean_absolute_error: 0.0079 - val_loss: 2.0555e-04 - val_mean_absolute_error: 0.0093
# Epoch 28/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3245e-04 - mean_absolute_error: 0.0079 - val_loss: 2.0525e-04 - val_mean_absolute_error: 0.0092
# Epoch 29/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3085e-04 - mean_absolute_error: 0.0078 - val_loss: 2.0482e-04 - val_mean_absolute_error: 0.0092
# Epoch 30/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2931e-04 - mean_absolute_error: 0.0078 - val_loss: 2.0424e-04 - val_mean_absolute_error: 0.0091
# Epoch 31/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2781e-04 - mean_absolute_error: 0.0077 - val_loss: 2.0352e-04 - val_mean_absolute_error: 0.0091
# Epoch 32/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2636e-04 - mean_absolute_error: 0.0077 - val_loss: 2.0266e-04 - val_mean_absolute_error: 0.0090
# Epoch 33/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2495e-04 - mean_absolute_error: 0.0076 - val_loss: 2.0167e-04 - val_mean_absolute_error: 0.0090
# Epoch 34/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2357e-04 - mean_absolute_error: 0.0076 - val_loss: 2.0057e-04 - val_mean_absolute_error: 0.0089
# Epoch 35/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2224e-04 - mean_absolute_error: 0.0075 - val_loss: 1.9937e-04 - val_mean_absolute_error: 0.0089
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2094e-04 - mean_absolute_error: 0.0075 - val_loss: 1.9809e-04 - val_mean_absolute_error: 0.0088
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1968e-04 - mean_absolute_error: 0.0075 - val_loss: 1.9675e-04 - val_mean_absolute_error: 0.0088
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1846e-04 - mean_absolute_error: 0.0074 - val_loss: 1.9537e-04 - val_mean_absolute_error: 0.0088
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1727e-04 - mean_absolute_error: 0.0074 - val_loss: 1.9396e-04 - val_mean_absolute_error: 0.0087
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1613e-04 - mean_absolute_error: 0.0073 - val_loss: 1.9253e-04 - val_mean_absolute_error: 0.0087
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1502e-04 - mean_absolute_error: 0.0073 - val_loss: 1.9109e-04 - val_mean_absolute_error: 0.0086
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1395e-04 - mean_absolute_error: 0.0073 - val_loss: 1.8966e-04 - val_mean_absolute_error: 0.0086
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1292e-04 - mean_absolute_error: 0.0072 - val_loss: 1.8825e-04 - val_mean_absolute_error: 0.0086
# Epoch 44/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1192e-04 - mean_absolute_error: 0.0072 - val_loss: 1.8685e-04 - val_mean_absolute_error: 0.0085
# Epoch 45/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1096e-04 - mean_absolute_error: 0.0072 - val_loss: 1.8548e-04 - val_mean_absolute_error: 0.0085
# Epoch 46/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1004e-04 - mean_absolute_error: 0.0071 - val_loss: 1.8415e-04 - val_mean_absolute_error: 0.0085
# Epoch 47/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0916e-04 - mean_absolute_error: 0.0071 - val_loss: 1.8285e-04 - val_mean_absolute_error: 0.0084
# Epoch 48/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0832e-04 - mean_absolute_error: 0.0071 - val_loss: 1.8160e-04 - val_mean_absolute_error: 0.0084
# Epoch 49/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0751e-04 - mean_absolute_error: 0.0070 - val_loss: 1.8038e-04 - val_mean_absolute_error: 0.0084
# Epoch 50/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0674e-04 - mean_absolute_error: 0.0070 - val_loss: 1.7922e-04 - val_mean_absolute_error: 0.0084

# %%
# Visualize GRU training performance

plot_training_curves(
    gru_history,
    "Improved GRU"
)

# %%
# Evaluate GRU on held-out future test data

evaluate_and_plot(
    gru_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Improved GRU"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Improved GRU Train RMSE: 405.75
# Improved GRU Test RMSE: 1108.27
# Improved GRU Train MAE: 270.35
# Improved GRU Test MAE: 641.07

# %% [markdown]
# Here I increased the number of GRU units from the baseline to 16, and increased the lookback window to 14 steps. The improved GRU model had the best performance across all of the recurrent models tested. Both RMSE and MAE decreased on the training and test sets, showing more accurate forecasts. The biggest improvement was where RMSE decreased by 77% and MAE decreased by 80%. The combination of the larger GRU layer and a longer 14 step lookback window improved the model's ability to learning patterns and generalize.

# %% [markdown]
# ### Your summary

# %% [markdown]
# The improved GRU model had the predictions that were much closer to the actual values, which makes it the best model across all of the recurrent neural network model I experimented with.

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# ### Do you need RNN for time series data?
#
# #### XGB with lagged features

# %% [markdown]
# Plotting function for nonscaled models

# %%
# Generic prediction plotting function for models already on the original scale

def plot_predictions(actual, predicted, title):

    plt.figure(figsize=(10, 4))

    plt.plot(actual, label="Actual")
    plt.plot(predicted, label="Predicted")

    plt.title(title)
    plt.xlabel("Test time index")
    plt.ylabel("Bitcoin Close Price (USD)")

    plt.ticklabel_format(style="plain", axis="y")

    plt.legend()
    plt.show()

# %% [markdown]
# XGB Data preparation

# %%
# Create lagged features for XGBoost

xgb_data = bitcoin[["date"] + features].copy()

lag_days = 10

for lag in range(1, lag_days + 1):
    for col in features:
        xgb_data[f"{col}_lag{lag}"] = xgb_data[col].shift(lag)

xgb_data["target_close_USD"] = xgb_data["close_USD"]

xgb_data = xgb_data.dropna().reset_index(drop=True)

xgb_data.head()
# Out:
#         date  open_USD  high_USD  low_USD  close_USD  volume  open_USD_lag1  \
# 0 2018-05-17   8330.00   8464.00  7979.00    8041.46   25439        8462.00
# 1 2018-05-18   8038.82   8273.21  7911.90    8239.81   23476        8330.00
# 2 2018-05-19   8238.01   8390.80  8095.73    8233.49   17193        8038.82
# 3 2018-05-20   8233.49   8609.00  8163.90    8526.98   19957        8238.01
# 4 2018-05-21   8526.97   8595.31  8305.00    8381.24   21516        8233.49
#
#    high_USD_lag1  low_USD_lag1  close_USD_lag1  ...  high_USD_lag9  \
# 0        8488.00       8083.01         8330.00  ...        9475.70
# 1        8464.00       7979.00         8041.46  ...        9390.00
# 2        8273.21       7911.90         8239.81  ...        9395.12
# 3        8390.80       8095.73         8233.49  ...        9016.80
# 4        8609.00       8163.90         8526.98  ...        8646.88
#
#    low_USD_lag9  close_USD_lag9  volume_lag9  open_USD_lag10  high_USD_lag10  \
# 0       9060.54         9187.56      25533.0         9661.02         9689.67
# 1       8965.00         9310.00      25673.0         9365.00         9475.70
# 2       8970.00         9002.20      25055.0         9178.00         9390.00
# 3       8341.00         8400.00      48227.0         9310.00         9395.12
# 4       8153.00         8465.94      40241.0         9002.21         9016.80
#
#    low_USD_lag10  close_USD_lag10  volume_lag10  target_close_USD
# 0        9181.00          9365.00       33787.0           8041.46
# 1        9060.54          9187.56       25533.0           8239.81
# 2        8965.00          9310.00       25673.0           8233.49
# 3        8970.00          9002.20       25055.0           8526.98
# 4        8341.00          8400.00       48227.0           8381.24
#
# [5 rows x 57 columns]

# %% [markdown]
# XGB train test preparation

# %%
# Prepare XGBoost train/test data

xgb_features = [
    col for col in xgb_data.columns
    if "lag" in col
]

X_xgb = xgb_data[xgb_features]
y_xgb = xgb_data["target_close_USD"]

train_size_xgb = int(len(xgb_data) * 0.8)

trainX_xgb = X_xgb.iloc[:train_size_xgb]
testX_xgb = X_xgb.iloc[train_size_xgb:]

trainY_xgb = y_xgb.iloc[:train_size_xgb]
testY_xgb = y_xgb.iloc[train_size_xgb:]

print("trainX_xgb shape:", trainX_xgb.shape)
print("testX_xgb shape:", testX_xgb.shape)
print("trainY_xgb shape:", trainY_xgb.shape)
print("testY_xgb shape:", testY_xgb.shape)
# Out:
# trainX_xgb shape: (792, 50)
# testX_xgb shape: (198, 50)
# trainY_xgb shape: (792,)
# testY_xgb shape: (198,)

# %% [markdown]
# Build & train model

# %%
# Build and train baseline XGBoost model

from xgboost import XGBRegressor

xgb_model = XGBRegressor(
    n_estimators=100,
    max_depth=3,
    learning_rate=0.1,
    objective="reg:squarederror",
    random_state=42
)

xgb_model.fit(
    trainX_xgb,
    trainY_xgb
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# Evaluating on test data

# %%
# Evaluate XGBoost baseline on held-out future test data

xgb_test_pred = xgb_model.predict(testX_xgb)

xgb_rmse = np.sqrt(mean_squared_error(testY_xgb, xgb_test_pred))
xgb_mae = mean_absolute_error(testY_xgb, xgb_test_pred)

print(f"Baseline XGBoost Test RMSE: {xgb_rmse:.2f}")
print(f"Baseline XGBoost Test MAE: {xgb_mae:.2f}")
# Out:
# Baseline XGBoost Test RMSE: 10490.81
# Baseline XGBoost Test MAE: 6340.83

# %%
# Visualize baselineXGBoost predictions

plot_predictions(
    testY_xgb.values,
    xgb_test_pred,
    "Baseline XGBoost Test Predictions"
)

# %% [markdown]
# Modifying the XGB target to percent change instead of raw price

# %%
# Improved XGBoost: predict next-day percent change instead of raw price

xgb_return_data = bitcoin[["date"] + features].copy()

xgb_return_data["close_return"] = (
    xgb_return_data["close_USD"]
    .pct_change()
)                                                               # calculate daily percent return

lag_days = 10                                                   # use previous 10 days as predictors

for lag in range(1, lag_days + 1):

    for col in features:
        xgb_return_data[f"{col}_lag{lag}"] = (
            xgb_return_data[col]
            .shift(lag)
        )                                                       # previous feature values become lag predictors

    xgb_return_data[f"close_return_lag{lag}"] = (
        xgb_return_data["close_return"]
        .shift(lag)
    )                                                           # include lagged returns as predictors

xgb_return_data["target_return"] = (
    xgb_return_data["close_return"]
    .shift(-1)
)                                                               # predict next-day return

xgb_return_data["current_close_USD"] = (
    xgb_return_data["close_USD"]
)                                                               # keep current close price for reconstruction later

xgb_return_data = (
    xgb_return_data
    .dropna()
    .reset_index(drop=True)
)                                                               # remove rows without sufficient lag history

xgb_return_features = [
    col for col in xgb_return_data.columns
    if "lag" in col
]                                                               # use lagged values as predictors

X_xgb_return = xgb_return_data[xgb_return_features]
y_xgb_return = xgb_return_data["target_return"]

train_size_xgb_return = int(len(xgb_return_data) * 0.8)        # chronological 80/20 split

trainX_xgb_return = X_xgb_return.iloc[:train_size_xgb_return]
testX_xgb_return = X_xgb_return.iloc[train_size_xgb_return:]

trainY_xgb_return = y_xgb_return.iloc[:train_size_xgb_return]
testY_xgb_return = y_xgb_return.iloc[train_size_xgb_return:]

test_current_close = (
    xgb_return_data["current_close_USD"]
    .iloc[train_size_xgb_return:]
)                                                               # current price used to reconstruct next-day prediction

xgb_return_model = XGBRegressor(
    n_estimators=300,                                           # more trees for stronger learning
    max_depth=2,                                                # shallow trees reduce overfitting
    learning_rate=0.03,                                         # smaller learning steps
    subsample=0.8,                                              # random row sampling
    colsample_bytree=0.8,                                       # random feature sampling
    objective="reg:squarederror",
    random_state=42
)

xgb_return_model.fit(
    trainX_xgb_return,
    trainY_xgb_return
)

xgb_return_pred = xgb_return_model.predict(
    testX_xgb_return
)                                                               # predict next-day percent return

xgb_return_price_pred = (
    test_current_close.values * (1 + xgb_return_pred)
)                                                               # convert predicted return back to predicted price

xgb_return_price_actual = (
    test_current_close.values * (1 + testY_xgb_return.values)
)                                                               # actual next-day price

xgb_return_rmse = np.sqrt(
    mean_squared_error(
        xgb_return_price_actual,
        xgb_return_price_pred
    )
)

xgb_return_mae = mean_absolute_error(
    xgb_return_price_actual,
    xgb_return_price_pred
)

print(f"Improved XGBoost Test RMSE: {xgb_return_rmse:.2f}")
print(f"Improved XGBoost Test MAE: {xgb_return_mae:.2f}")

plot_predictions(
    xgb_return_price_actual,
    xgb_return_price_pred,
    "Improved XGBoost Return-Based Test Predictions"
)
# Out:
# Improved XGBoost Test RMSE: 925.44
# Improved XGBoost Test MAE: 564.97

# %%
# Compare baseline model performance

simple_rnn_rmse, simple_rnn_mae = evaluate_metrics(
    simple_rnn_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

lstm_rmse, lstm_mae = evaluate_metrics(
    lstm_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

gru_rmse, gru_mae = evaluate_metrics(
    gru_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

model_comparison = pd.DataFrame({
    "Model": [
        "SimpleRNN",
        "LSTM",
        "GRU",
        "XGBoost raw price target",
        "XGBoost return target"
    ],

    "RMSE": [
        simple_rnn_rmse,
        lstm_rmse,
        gru_rmse,
        xgb_rmse,
        xgb_return_rmse
    ],

    "MAE": [
        simple_rnn_mae,
        lstm_mae,
        gru_mae,
        xgb_mae,
        xgb_return_mae
    ]
})

model_comparison.sort_values("RMSE")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#                       Model          RMSE          MAE
# 4     XGBoost return target    925.441209   564.967019
# 2                       GRU   1108.266941   641.072704
# 1                      LSTM   2337.834369  1567.217074
# 0                 SimpleRNN   2839.883895  1645.439687
# 3  XGBoost raw price target  10490.806519  6340.832358

# %% [markdown]
# The overall results after experimenting and comparing against XGBoost results show that the model choice and target transformation have a significant impact on forecasting performance. The XGBoost model trained on return targets had the lowest forecasting errors overall, but the GRU was the strongest recurrent neural network architecture. Both LSTM and GRU outperformed the SimpleRNN baseline, meaning the tuning and experimentations in look_back and architecture had an impact on the patterns gathered in the Bitcoin data. Transforming the target variable from raw prices to returns improved accuracy because of the preprocessing steps.
